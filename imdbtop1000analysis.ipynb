# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('imdb top 1000 movies.csv')
X = df['releaseYear'].values
y = df['averageRating'].values

def calculate_slope(X, y):
    n = len(X)
    m = (n * np.sum(X * y) - np.sum(X) * np.sum(y)) / (n * np.sum(X ** 2) - np.sum(X) ** 2)
    return m

def calculate_int(X,y):
    n = len(X)
    b = (np.sum(y) - m * np.sum(X)) / n
    return b


def predict(X, m, b):
    return m * X + b

def mean_squared_error(y_act, y_pred):
    return np.mean((y_act - y_pred) ** 2)

m = calculate_slope(X, y)
b=calculate_int(X,y)
y_pred = predict(X, m, b)

mse = mean_squared_error(y, y_pred)
print("mean squared error: ", {mse})

plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# mean squared error:  {0.06380132789088726}
